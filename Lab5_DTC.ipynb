# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
data= pd.read_csv('Data4.csv')

# %%
data.head(5)
# Out:
#            id          name  est_diameter_min  est_diameter_max  \
# 0   3561024.0    (2011 GZ2)          0.016016          0.035813
# 1  54016766.0    (2020 HT6)          0.030518          0.068240
# 2   3746620.0  (2016 ED156)          0.055533          0.124177
# 3   3633054.0    (2013 FD8)          0.019256          0.043057
# 4   3742124.0   (2016 CW31)          0.139494          0.311918
#
#    relative_velocity  miss_distance  absolute_magnitude  hazardous
# 0       56014.078517   1.024333e+06                26.1      False
# 1        7864.348060   3.268186e+07                24.7      False
# 2       55257.544508   6.538636e+07                23.4      False
# 3       41531.404722   1.260796e+07                25.7      False
# 4       67639.394481   7.130590e+07                21.4      False

# %%
data.isna().sum()
# Out:
# id                    570
# name                   46
# est_diameter_min        0
# est_diameter_max      457
# relative_velocity     557
# miss_distance           0
# absolute_magnitude    684
# hazardous               0
# dtype: int64

# %%
data.describe()
# Out:
#                  id  est_diameter_min  est_diameter_max  relative_velocity  \
# count  9.026600e+04      90836.000000      90379.000000       90279.000000
# mean   1.438528e+07          0.127432          0.284911       48066.003701
# std    2.087357e+07          0.298511          0.668148       25294.523635
# min    2.000433e+06          0.000609          0.001362         203.346433
# 25%    3.448595e+06          0.019256          0.043057       28620.469765
# 50%    3.748364e+06          0.048368          0.108153       44190.108201
# 75%    3.884023e+06          0.143402          0.320656       62931.850541
# max    5.427591e+07         37.892650         84.730541      236990.128088
#
#        miss_distance  absolute_magnitude
# count   9.083600e+04        90152.000000
# mean    3.706655e+07           23.526653
# std     2.235204e+07            2.893982
# min     6.745533e+03            9.230000
# 25%     1.721082e+07           21.340000
# 50%     3.784658e+07           23.700000
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['id']=data['id'].map(lambda y: np.random.uniform(((data['id'].min()).round()), ((data['id'].max()).round()) if pd.isna(y) else y))
data['id']
# Out:
# 0        3.116132e+06
# 1        6.985097e+06
# 2        2.465453e+06
# 3        2.113864e+06
# 4        2.241233e+06
#              ...
# 90831    1.157090e+07
# 90832    2.532922e+06
# 90833    2.227029e+06
# 90834    3.265553e+06
# 90835    2.477488e+06
# Name: id, Length: 90836, dtype: float64

# %%
data.pop('name')
# Out:
# 0          (2011 GZ2)
# 1          (2020 HT6)
# 2        (2016 ED156)
# 3          (2013 FD8)
# 4         (2016 CW31)
#              ...
# 90831       (2021 YE)
# 90832       (2018 KL)
# 90833    (2016 AB166)
# 90834    (2014 SQ260)
# 90835      (2012 EQ3)
# Name: name, Length: 90836, dtype: object

# %%
data['est_diameter_max']=data['est_diameter_max'].map(lambda y: np.random.uniform(((data['est_diameter_max'].min()).round()), ((data['est_diameter_max'].max()).round()) if pd.isna(y) else y))
data['est_diameter_max']
# Out:
# 0        0.019195
# 1        0.019800
# 2        0.073999
# 3        0.025174
# 4        0.155308
#            ...
# 90831    0.025791
# 90832    0.131402
# 90833    0.025958
# 90834    0.016324
# 90835    0.157830
# Name: est_diameter_max, Length: 90836, dtype: float64

# %%
data['relative_velocity']=data['relative_velocity'].map(lambda y: np.random.uniform(((data['relative_velocity'].min()).round()), ((data['relative_velocity'].max()).round()) if pd.isna(y) else y))
data['relative_velocity']
# Out:
# 0         3009.001720
# 1          286.025761
# 2          849.948476
# 3        27535.093048
# 4        15541.795495
#              ...
# 90831     4565.411310
# 90832      991.129644
# 90833    51738.437686
# 90834    14660.675585
# 90835    13884.292144
# Name: relative_velocity, Length: 90836, dtype: float64

# %%
data['absolute_magnitude']=data['absolute_magnitude'].map(lambda y: np.random.uniform(((data['absolute_magnitude'].min()).round()), ((data['absolute_magnitude'].max()).round()) if pd.isna(y) else y))
data['absolute_magnitude']
# Out:
# 0         9.888666
# 1        19.263760
# 2        19.656970
# 3        20.622191
# 4        15.064203
#            ...
# 90831    10.043992
# 90832    18.351321
# 90833    15.411999
# 90834    10.186625
# 90835    14.622745
# Name: absolute_magnitude, Length: 90836, dtype: float64

# %%
data.isna().sum()
# Out:
# id                    0
# est_diameter_min      0
# est_diameter_max      0
# relative_velocity     0
# miss_distance         0
# absolute_magnitude    0
# hazardous             0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.loc[(data['hazardous'] == "True"), 'hazardous'] = 1
data.loc[(data['hazardous'] == "False"), 'hazardous'] = 0

# %%
data.describe()[['id', 'est_diameter_min', 'est_diameter_max', 'relative_velocity', 'miss_distance', 'absolute_magnitude']]
columns = ['id', 'est_diameter_min', 'est_diameter_max', 'relative_velocity', 'miss_distance', 'absolute_magnitude']

for column in columns:
    data.hist(column)

# %%
outlier = data[['id', 'est_diameter_min', 'est_diameter_max', 'relative_velocity', 'miss_distance', 'absolute_magnitude']]
outlier
# Out:
#                  id  est_diameter_min  est_diameter_max  relative_velocity  \
# 0      3.116132e+06          0.016016          0.019195        3009.001720
# 1      6.985097e+06          0.030518          0.019800         286.025761
# 2      2.465453e+06          0.055533          0.073999         849.948476
# 3      2.113864e+06          0.019256          0.025174       27535.093048
# 4      2.241233e+06          0.139494          0.155308       15541.795495
# ...             ...               ...               ...                ...
# 90831  1.157090e+07          0.017561          0.025791        4565.411310
# 90832  2.532922e+06          0.110804          0.131402         991.129644
# 90833  2.227029e+06          0.035039          0.025958       51738.437686
# 90834  3.265553e+06          0.044112          0.016324       14660.675585
# 90835  2.477488e+06          0.084441          0.157830       13884.292144
#
#        miss_distance  absolute_magnitude
# ...

# %%
Q1 = outlier.quantile(0.25)
Q1
# Out:
# id                    2.104503e+06
# est_diameter_min      1.925551e-02
# est_diameter_max      1.514359e-02
# relative_velocity     2.714980e+03
# miss_distance         1.721082e+07
# absolute_magnitude    1.247469e+01
# Name: 0.25, dtype: float64

# %%
Q3 = outlier.quantile(0.75)
Q3
# Out:
# id                    3.047952e+06
# est_diameter_min      1.434019e-01
# est_diameter_max      1.428828e-01
# relative_velocity     1.698846e+04
# miss_distance         5.654900e+07
# absolute_magnitude    1.964187e+01
# Name: 0.75, dtype: float64

# %%
IQR = Q3-Q1
data_filtered = outlier[~((outlier < (Q1 - 1.5 * IQR)) |(outlier > (Q3 + 1.5 * IQR))).any(axis=1)]
data_filtered
# Out:
#                  id  est_diameter_min  est_diameter_max  relative_velocity  \
# 0      3.116132e+06          0.016016          0.019195        3009.001720
# 2      2.465453e+06          0.055533          0.073999         849.948476
# 3      2.113864e+06          0.019256          0.025174       27535.093048
# 4      2.241233e+06          0.139494          0.155308       15541.795495
# 5      2.226404e+06          0.046191          0.025036        3297.554794
# ...             ...               ...               ...                ...
# 90828  2.518804e+06          0.024241          0.015083        1015.003535
# 90830  2.669972e+06          0.008405          0.002602        3287.389234
# 90832  2.532922e+06          0.110804          0.131402         991.129644
# 90834  3.265553e+06          0.044112          0.016324       14660.675585
# 90835  2.477488e+06          0.084441          0.157830       13884.292144
#
#        miss_distance  absolute_magnitude
# ...

# %%
index_list = list(data_filtered.index.values)
data_filtered = data[data.index.isin(index_list)]
data_filtered.head()
# Out:
#              id  est_diameter_min  est_diameter_max  relative_velocity  \
# 0  3.116132e+06          0.016016          0.019195        3009.001720
# 2  2.465453e+06          0.055533          0.073999         849.948476
# 3  2.113864e+06          0.019256          0.025174       27535.093048
# 4  2.241233e+06          0.139494          0.155308       15541.795495
# 5  2.226404e+06          0.046191          0.025036        3297.554794
#
#    miss_distance  absolute_magnitude hazardous
# 0   1.024333e+06            9.888666     False
# 2   6.538636e+07           19.656970     False
# 3   1.260796e+07           20.622191     False
# 4   7.130590e+07           15.064203     False
# 5   2.847083e+07           17.235273     False

# %%
filtered_outlier = data_filtered[['id', 'est_diameter_min', 'est_diameter_max', 'relative_velocity', 'miss_distance', 'absolute_magnitude']]

for col in filtered_outlier:
    data_filtered.hist(col, bins=100)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90836 entries, 0 to 90835
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  90836 non-null  float64
#  1   est_diameter_min    90836 non-null  float64
#  2   est_diameter_max    90836 non-null  float64
#  3   relative_velocity   90836 non-null  float64
#  4   miss_distance       90836 non-null  float64
#  5   absolute_magnitude  90836 non-null  float64
#  6   hazardous           90836 non-null  object
# dtypes: float64(6), object(1)
# memory usage: 4.9+ MB

# %%
data_filtered.loc[(data_filtered['hazardous'] == "True"), 'hazardous'] = 1
data_filtered.loc[(data_filtered['hazardous'] == "False"), 'hazardous'] = 0
data_filtered['hazardous'] = data_filtered['hazardous'].astype(float)

# %%
pd.crosstab(data_filtered['hazardous'],data_filtered['hazardous'], normalize='all')*100
# Out:
# hazardous        0.0       1.0
# hazardous
# 0.0        92.185637  0.000000
# 1.0         0.000000  7.814363

# %%
data_filtered = data_filtered[['hazardous', 'id', 'est_diameter_min', 'est_diameter_max', 'relative_velocity', 'miss_distance', 'absolute_magnitude']]

# %%
fig, ax = plt.subplots(figsize=(15, 10))
sns.heatmap(data_filtered.corr(), cmap='coolwarm',annot=True)
plt.show()

# %%
sns.set_style('whitegrid')
sns.pairplot(data_filtered, hue= 'hazardous')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import numpy as np
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn import datasets
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.tree import plot_tree

import category_encoders as ce
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, mean_squared_error
from sklearn.metrics import r2_score

# %%
y = data_filtered["hazardous"]
X = data_filtered.drop("hazardous", axis = 1)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=1000)

# %%
X_train.head()
# Out:
#                  id  est_diameter_min  est_diameter_max  relative_velocity  \
# 86490  2.119806e+06          0.025384          0.047174        1105.970414
# 34680  2.246785e+06          0.003842          0.004714         414.924333
# 77359  2.052771e+06          0.175612          0.265693        1146.961465
# 32982  2.519647e+06          0.048368          0.005929        1908.634932
# 12759  2.345587e+06          0.027833          0.025026       23594.782091
#
#        miss_distance  absolute_magnitude
# 86490   2.699004e+07           10.926408
# 34680   3.157281e+07           16.065141
# 77359   7.283030e+07           16.013146
# 32982   4.974320e+07           10.998676
# 12759   6.139115e+06           17.799074

# %%
from sklearn.tree import DecisionTreeClassifier, export_text

# %%
Tree_classifier = DecisionTreeClassifier()
Tree_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
Tree_classifier.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
Tree_classifier.get_depth()
# Out:
# 43

# %%
y_hat = Tree_classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score
from sklearn.model_selection import cross_val_score

# %%
print(confusion_matrix(y_test, y_hat))
# Out:
# [[10416   571]
#  [  528   397]]

# %%
print(classification_report(y_test, y_hat))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95     10987
#          1.0       0.41      0.43      0.42       925
#
#     accuracy                           0.91     11912
#    macro avg       0.68      0.69      0.68     11912
# weighted avg       0.91      0.91      0.91     11912

# %%
path = DecisionTreeClassifier().cost_complexity_pruning_path(X_train,y_train)
ccp_alphas = path.ccp_alphas

# %%
len(ccp_alphas)
# Out:
# 1118

# %%
path.keys()
# Out:
# dict_keys(['ccp_alphas', 'impurities'])

# %%
path
# Out:
# {'ccp_alphas': array([0.00000000e+00, 1.34926465e-05, 1.39919714e-05, ...,
#         1.00929010e-03, 6.83109250e-03, 3.77924783e-02]),
#  'impurities': array([0.00000000e+00, 4.04779395e-05, 8.24538538e-05, ...,
#         9.96578774e-02, 1.06488970e-01, 1.44281448e-01])}

# %%
accuracy_cv =[]
for alpha in ccp_alphas:
    accuracy = cross_val_score(estimator = DecisionTreeClassifier(ccp_alpha=alpha), X = X_train, y = y_train, cv = 5 , scoring="accuracy" )
    accuracy_cv.append(np.mean(accuracy))

output = pd.DataFrame(list(ccp_alphas), columns=['alpha'])
output['accuracy_CV']=accuracy_cv

output.head()

# %%
sns.lineplot(x='alpha', y='accuracy_CV', data=output , color='b', label="accuracy_CV vs alpha")
plt.show()

# %%
output.iloc[np.argmax(output['accuracy_CV']),]

# %%
optimal_alpha = output.iloc[np.argmax(output['accuracy_CV']),0]
optimal_alpha

# %% [markdown]
# ## Оценка модели

# %%
from sklearn.model_selection import cross_val_score

# %%
accuracy = cross_val_score(estimator = optimal_DT, X = X_train, y = y_train, cv = 5 , scoring="accuracy" )

# %%
accuracy

# %%
round(accuracy.mean(),3)

# %% [markdown]
# ## Визуализация Tree

# %%
data_filtered.columns

# %%
sns.scatterplot(x='relative_velocity', y='absolute_magnitude', data=df, hue='hazardous')
plt.show()

# %%
dtree= DecisionTreeClassifier(max_depth=2)
dtree.fit(X_train, y_train)
yhat = dtree.predict(X_test)

# %%
from sklearn.tree import plot_tree

# %%
X_train.shape

# %%
X_train.head()

# %%
fig = plt.figure(figsize=(20,15))
DT_plot = plot_tree(dtree, feature_names=X_train.columns.tolist(), filled=True)

# %%
fig.savefig("DT_plot_classification.png")

# %% [markdown]
# ## Решающие правила

# %%
tree_rules = export_text(Tree_classifier, feature_names=list(X.columns))
print(tree_rules)

# %% [markdown]
# ## CART

# %%
tree_classifier = DecisionTreeClassifier(random_state=42)
tree_classifier.fit(X_train, y_train)

# %% [markdown]
# ## BaggingClassifier

# %%
from sklearn.ensemble import BaggingClassifier
clf = BaggingClassifier(estimator=dtree, n_estimators=10).fit(X_train, y_train)
y_bc_pred = clf.predict(X_test)

accuracy = cross_val_score(estimator = clf, X = X_train, y = y_train, cv = 5 , scoring="accuracy" )
print("Accuracy:", round(accuracy.mean(),3))

# %% [markdown]
# ## GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
clf = GradientBoostingClassifier(n_estimators=20, learning_rate=0.5, max_features=2, max_depth=2, random_state=0)
clf.fit(X_train, y_train)
predict = clf.predict(X_test)

# %%
print("Confusion Matrix:")
print(confusion_matrix(y_test, predict))

print("Classification Report")
print(classification_report(y_test, predict))
accuracy = cross_val_score(estimator = clf, X = X_train, y = y_train, cv = 5 , scoring="accuracy" )
print("Accuracy:", round(accuracy.mean(),3))

# %% [markdown]
# ## StackingClassifier

# %%
from sklearn.ensemble import StackingClassifier
clf = StackingClassifier(estimators = [("dtr", dtree)], final_estimator=dtree).fit(X_train, y_train)
y_sc_pred = clf.predict(X_test)

accuracy = cross_val_score(estimator = clf, X = X_train, y = y_train, cv = 5 , scoring="accuracy" )
print("Accuracy:", round(accuracy.mean(),3))
